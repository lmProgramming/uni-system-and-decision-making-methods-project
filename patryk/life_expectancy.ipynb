# %% [markdown]
# # Imports

# %%
import matplotlib.pyplot as plt
from api import api
import pandas as pd
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.tree import DecisionTreeRegressor
import numpy as np
import seaborn as sns
from itertools import product
import random

# %% [markdown]
# # Retrieve data

# %%
# initialize api caller
apiCaller = api()

countries = apiCaller.getCountries()
lifeExpectancy = apiCaller.getValues("WHOSIS_000001")
popuation = apiCaller.getValues("RS_1845")
alcoholConsumption = apiCaller.getValues("SA_0000001688")
hospitalBeds = apiCaller.getValues("WHS6_102")
hdiRanking = apiCaller.getValues("CCO_2")
gniPerCapita = apiCaller.getValues("RS_576")
hospitalDensity = apiCaller.getValues("DEVICES00")
ict = apiCaller.getValues("ITU_IDI")
nutritionScore = apiCaller.getValues("NLIS_NU_CA_023")
cigaretteLowestPrice = apiCaller.getValues("R_Price_lowest_cost_usd")
povertyRate = apiCaller.getValues("NLIS_NU_CA_084")
beerPrice = apiCaller.getValues("SA_0000001829")
openDefecation = apiCaller.getValues("WSH_SANITATION_OD")
healthExpenditure = apiCaller.getValues("GHED_CHEGDP_SHA2011")
indicators = [lifeExpectancy,popuation,alcoholConsumption,hospitalBeds,hdiRanking,gniPerCapita,hospitalDensity,ict,nutritionScore,cigaretteLowestPrice,povertyRate,beerPrice,openDefecation,healthExpenditure]

# combine indicators into one dataframe
df = pd.DataFrame(apiCaller.combineIndicators(indicators=indicators)).T
# drop rows with missing target values
df.dropna(subset=[df.columns[0]],how='any',inplace=True)
for col in df.columns:
    df[col] = pd.to_numeric(df[col],errors='coerce')
df.sort_values(by=df.columns[0],ascending=False,inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 183 entries, Portugal to Burundi
# Data columns (total 14 columns):
#  #   Column                                                                                         Non-Null Count  Dtype
# ---  ------                                                                                         --------------  -----
#  0   Life expectancy at birth (years)                                                               183 non-null    float64
#  1   Population                                                                                     173 non-null    float64
#  2   Alcohol, total per capita (15+) consumption (in litres of pure alcohol) (SDG Indicator 3.5.2)  178 non-null    float64
#  3   Hospital beds (per 10 000 population)                                                          178 non-null    float64
#  4   Human development index rank                                                                   181 non-null    float64
#  5   Gross national income per capita (Atlas method)                                                171 non-null    float64
#  6   Total density per 100 000 population: Hospitals                                                130 non-null    float64
#  7   ICT Development Index (IDI)                                                                    155 non-null    float64
#  8   Nutrition Governance score                                                                     183 non-null    float64
#  9   Cheapest brand of cigarettes - price in US$ at official exchange rates                         163 non-null    float64
#  10  Population below the international poverty line (%)                                            160 non-null    float64
#  11  Average price 500 mls Beer in US$                                                              162 non-null    float64
#  12  Population practising open defecation (%)                                                      183 non-null    float64
#  13  Current health expenditure (CHE) as percentage of gross domestic product (GDP) (%)             181 non-null    float64
# dtypes: float64(14)
# memory usage: 21.4+ KB

# %% [markdown]
# # Missing values

# %% [markdown]
# useful when it comes to long label names

# %%
def shorten_labels(labels, max_length=20) -> list[str]:
    new_labels = []
    for label in labels:
        label = label.get_text()
        if len(label) > max_length:
            new_labels.append(label[:max_length] + "...")
        else:
            new_labels.append(label)
    return new_labels

# %%
def show_missing_values(df: pd.DataFrame) -> None:
    plt.figure(figsize=(12,5))
    y = (df.isnull().sum() * 100 / len(df))
    ax = sns.barplot(x=df.columns,y=y,palette='RdYlGn_r',hue=y)
    plt.xticks(rotation=90)
    plt.ylabel('% of missing data')
    plt.xlabel('Indicators')
    plt.legend(title='% of missing data')   
    ax.set_xticks(range(len(df.columns)))
    ax.xaxis.set_ticklabels(shorten_labels(ax.xaxis.get_ticklabels(),30))
    plt.show()
show_missing_values(df)

# %% [markdown]
# Around 30% of hospitals indicator data is missing, it will be removed later

# %% [markdown]
# # Life expectancy buckets

# %%
plt.figure(figsize=(12,5))
sns.histplot(df['Life expectancy at birth (years)'],bins=10,kde=True,color='green')
plt.show()

# %% [markdown]
# # Sample values per country
# Presented sample values of "Life expectancy" per country

# %%
sample = df.sample(10)
sample = sample.sort_values(by=sample.columns[0],ascending=False)
plt.figure(figsize=(12,5))
sns.barplot(x=sample.index,y=sample[sample.columns[0]],hue=sample.columns[0],data=sample,legend=False,palette='RdYlGn')
plt.xlabel("Country")
plt.xticks(rotation=45)
plt.ylabel("Life expectancy")
plt.ylim(30,90)
plt.show()

# %% [markdown]
# # Dependencies between indicators and target - Life expectancy

# %%
def corealtion_matrix(df: pd.DataFrame) -> None:
    plt.figure(figsize=(12,8))
    ax = sns.heatmap(df.corr(),annot=True,cmap='viridis',fmt='.2f')
    new_labels = shorten_labels(ax.xaxis.get_ticklabels(),30)
    ax.xaxis.set_ticklabels(new_labels)
    ax.yaxis.set_ticklabels(new_labels)
    plt.show()
corealtion_matrix(df)

# %%
def visualise_scatter(x,y,data,show_reg=True,xlim=None,ylim=None) -> None:
    plt.figure(figsize=(12,5))
    sns.scatterplot(data=data,x=x,y=y,hue=y,palette='RdYlGn')
    if show_reg:
        sns.regplot(data=data,x=x,y=y,scatter=False,truncate=True,order=3,color='0.2')
    plt.ylim(ylim)
    plt.xlim(xlim)
    plt.show()

# %% [markdown]
# ### Population

# %%
visualise_scatter(x=df.columns[1],y=df.columns[0],data=df,show_reg=False,ylim=(45,90))

# %% [markdown]
# as we can see, the population of the country doesn't have any impact on the life expectancy and it will only make the calculations less reliable, so it has to be erased later.

# %% [markdown]
# # Alcohol consumption per capita

# %%
visualise_scatter(x=df.columns[2],y=df.columns[0],data=df,show_reg=True,ylim=(45,90))

# %% [markdown]
# # Hospital beds

# %%
visualise_scatter(x=df.columns[3],y=df.columns[0],data=df,show_reg=True)

# %% [markdown]
# # HDI rank (1 - highest)

# %%
visualise_scatter(x=df.columns[4],y=df.columns[0],data=df,show_reg=True,ylim=(45,90),xlim=(1))

# %% [markdown]
# # GNI per capita

# %%
visualise_scatter(x=df.columns[5],y=df.columns[0],data=df,show_reg=True,ylim=(45,90))

# %% [markdown]
# # Hospitals
# the x axis has been limited, because some random country had hospital density set to 50 and it ruined the whole visualisation

# %%
visualise_scatter(x=df.columns[6],y=df.columns[0],data=df,show_reg=True,ylim=(45,90),xlim=(0,10))

# %% [markdown]
# # ICT

# %%
visualise_scatter(x=df.columns[7],y=df.columns[0],data=df,show_reg=True,ylim=(45,90))

# %% [markdown]
# # Nutrition Governance score

# %%
visualise_scatter(x=df.columns[8],y=df.columns[0],data=df,show_reg=True,ylim=(45,90))

# %% [markdown]
# # Cheapest cigarettes price

# %%
visualise_scatter(x=df.columns[9],y=df.columns[0],data=df,show_reg=True,ylim=(45,90))

# %% [markdown]
# # Percentage of population living below the poverty line

# %%
visualise_scatter(x=df.columns[10],y=df.columns[0],data=df,show_reg=True,ylim=(30,90))

# %% [markdown]
# # Average price of 500ml beer

# %%
visualise_scatter(x=df.columns[11],y=df.columns[0],data=df,show_reg=True,ylim=(45,90))

# %% [markdown]
# # % of population practising open defecation

# %%
visualise_scatter(x=df.columns[12],y=df.columns[0],data=df,show_reg=True,ylim=(45,90))

# %% [markdown]
# # CHE as percentage of GPD

# %%
visualise_scatter(x=df.columns[13],y=df.columns[0],data=df,show_reg=True,ylim=(45,90))

# %% [markdown]
# Removing irrelevant data

# %%
df.drop('Population',inplace=True,axis=1)
df.drop('Total density per 100 000 population: Hospitals',inplace=True,axis=1)
df['Alcohol, total per capita (15+) consumption (in litres of pure alcohol) (SDG Indicator 3.5.2)'] = df['Alcohol, total per capita (15+) consumption (in litres of pure alcohol) (SDG Indicator 3.5.2)'].fillna(df['Alcohol, total per capita (15+) consumption (in litres of pure alcohol) (SDG Indicator 3.5.2)'].mean())
df['Hospital beds (per 10 000 population)'] = df['Hospital beds (per 10 000 population)'].fillna(df['Hospital beds (per 10 000 population)'].mean(),)
df['Human development index rank'] = df['Human development index rank'].fillna(df['Human development index rank'].mean())
df.dropna(how='any',inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 115 entries, Portugal to Zimbabwe
# Data columns (total 12 columns):
#  #   Column                                                                                         Non-Null Count  Dtype
# ---  ------                                                                                         --------------  -----
#  0   Life expectancy at birth (years)                                                               115 non-null    float64
#  1   Alcohol, total per capita (15+) consumption (in litres of pure alcohol) (SDG Indicator 3.5.2)  115 non-null    float64
#  2   Hospital beds (per 10 000 population)                                                          115 non-null    float64
#  3   Human development index rank                                                                   115 non-null    float64
#  4   Gross national income per capita (Atlas method)                                                115 non-null    float64
#  5   ICT Development Index (IDI)                                                                    115 non-null    float64
#  6   Nutrition Governance score                                                                     115 non-null    float64
#  7   Cheapest brand of cigarettes - price in US$ at official exchange rates                         115 non-null    float64
#  8   Population below the international poverty line (%)                                            115 non-null    float64
#  9   Average price 500 mls Beer in US$                                                              115 non-null    float64
#  10  Population practising open defecation (%)                                                      115 non-null    float64
#  11  Current health expenditure (CHE) as percentage of gross domestic product (GDP) (%)             115 non-null    float64
# dtypes: float64(12)
# memory usage: 11.7+ KB

# %% [markdown]
# # Scaling the data

# %%
x = df.get(df.columns[1:]).values
y = df[df.columns[0]]
scaler = StandardScaler()
x = scaler.fit_transform(x,y)

# %% [markdown]
# # Choosing the best model

# %% [markdown]
# Running repetetive tests to measure the average accuracy of different regression models such as: Linear Regression, Ridge, Lasso, Random Forest Regressor and Decision Tree Regressor
#
# Model with the best scoring metrics will be choosen to base further calculations on

# %%
def test_models(x, y, models, repetitions=25) -> dict:
    '''Tests different models on the dataset and returns results in form of a dictionary with average metrics values'''
    results = {}
    for _ in range(repetitions):
        for model,name  in zip(models,[model.__class__.__name__ for model in models]):
            x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)
            model.fit(x_train, y_train)
            y_pred = model.predict(x_test)
            for metric, metricname in zip([mean_squared_error,mean_absolute_error,r2_score],['MSE','MAE','R2']):
                if name not in results:
                    results[name] = {}
                if metricname not in results[name]:
                    results[name][metricname] = []
                results[name][metricname].append(metric(y_test,y_pred))
                
    for key in results:
        for metric in results[key]:
            results[key][metric] = np.mean(results[key][metric])
    return results

results = test_models(x,y,[LinearRegression(),Ridge(),Lasso(),RandomForestRegressor(),DecisionTreeRegressor(),GradientBoostingRegressor(),ElasticNet()],repetitions=250)
results_df = pd.DataFrame(results).T
fig, ax= plt.subplots(ncols=3,figsize=(15,20))
sns.heatmap(results_df[['MSE']],annot=True,fmt='.2f',cmap='RdYlGn_r',ax=ax[0],cbar=False)
sns.heatmap(results_df[['MAE']],annot=True,fmt='.2f',cmap='RdYlGn_r',ax=ax[1],cbar=False)
sns.heatmap(results_df[['R2']],annot=True,fmt='.2f',cmap='RdYlGn',ax=ax[2],cbar=False)
# Out:
# <Axes: >

# %% [markdown]
# After running many tests, Random Forest Regressor, Gradient Boosting Regressor and Ridge models have been choosen for further testing

# %% [markdown]
# # Choosing best parameters for our models

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.20,random_state=42)

# %% [markdown]
# ## Random Forest Regressor

# %%
def best_forest_fit(x_train, y_train, x_test,y_test) -> tuple[RandomForestRegressor,dict]:
    '''Tests different parameters for RandomForestRegressor and returns the best model, its parameters and the score on the training set'''
    best_params = {}
    best_score = 0
    best_model = None
    for n_estimators, min_samples_split, min_samples_leaf,max_features in product([5,10,25,50],[5,10,15],[1,3,5],[0.2,'sqrt','log2',1]):
        model = RandomForestRegressor(n_jobs=1,n_estimators=n_estimators,max_depth=None,min_samples_split=min_samples_split,min_samples_leaf=min_samples_leaf,max_features=max_features,random_state=42)
        model.fit(x_train,y_train)
        y_pred = model.predict(x_test)
        score = r2_score(y_test,y_pred)
        if score > best_score:
            best_model = model
            best_score = score
            best_params = {'n_estimators':n_estimators,'min_samples_split':min_samples_split,'min_samples_leaf':min_samples_leaf,'max_features':max_features}
    return best_model, best_params

forest_model, forest_params = best_forest_fit(x_train,y_train,x_test,y_test)
print(forest_params)
# Out:
# {'n_estimators': 5, 'min_samples_split': 10, 'min_samples_leaf': 3, 'max_features': 0.2}

# %% [markdown]
# ## Gradient Boosting Regressor

# %%
def best_gradient_boosting_fit(x_train, y_train, x_test, y_test) -> tuple[GradientBoostingRegressor,dict]:
    '''Tests different parameters for Gradient Boosting Regressor and returns the best model, its parameters'''
    best_params = {}
    best_score = 0
    best_model = None
    for n_estimators, min_samples_split, min_samples_leaf,max_features,learning_rate in product([125,150,200,300],[2,5,10],[1,3,5],[0.2,'sqrt','log2',1],[0.05,0.075,0.1,0.15]):
        model = GradientBoostingRegressor(n_estimators=n_estimators,min_samples_split=min_samples_split,min_samples_leaf=min_samples_leaf,max_features=max_features,learning_rate=learning_rate,random_state=42)
        model.fit(x_train,y_train)
        y_pred = model.predict(x_test)
        score = r2_score(y_test,y_pred)
        if score > best_score:
            best_model = model
            best_score = score
            best_params = {'n_estimators':n_estimators,'min_samples_split':min_samples_split,'min_samples_leaf':min_samples_leaf,'max_features':max_features,'learning_rate':learning_rate}
    return best_model, best_params

gradient_model, gradient_params = best_gradient_boosting_fit(x_train,y_train,x_test,y_test)
print(gradient_params)
# Out:
# {'n_estimators': 300, 'min_samples_split': 10, 'min_samples_leaf': 3, 'max_features': 0.2, 'learning_rate': 0.15}

# %% [markdown]
# ## Ridge

# %%
def best_ridge_fit(x_train, y_train, x_test, y_test) -> tuple[Ridge,dict]:
    '''Tests different parameters for Ridge Regression and returns the best model, its parameters'''
    best_params = {}
    best_score = 0
    best_model = None
    for alpha,solver in product([0.5,1,2,5],['auto','svd','cholesky','lsqr','sparse_cg','sag','saga']):
        model = Ridge(alpha=alpha,solver=solver,random_state=42)
        model.fit(x_train,y_train)
        y_pred = model.predict(x_test)
        score = r2_score(y_test,y_pred)
        if score > best_score:
            best_model = model
            best_score = score
            best_params = {'alpha':alpha,'solver':solver}
    return best_model, best_params

ridge_model, ridge_params = best_ridge_fit(x_train,y_train,x_test,y_test)
print(ridge_params)
# Out:
# {'alpha': 2, 'solver': 'saga'}

# %% [markdown]
# # Comparsion between models

# %%
def plot_compare() -> None:
    fig, [ax1, ax2, ax3] = plt.subplots(ncols=3,figsize=(15,5))
    for metric,name,ax in zip([mean_squared_error,mean_absolute_error,r2_score],['MSE','MAE','R2'],[ax1,ax2,ax3]):
        y_pred_forest = forest_model.predict(x_test)
        y_pred_gradient = gradient_model.predict(x_test)
        y_pred_ridge = ridge_model.predict(x_test)
        y_values = [metric(y_test,y_pred_forest),metric(y_test,y_pred_gradient),metric(y_test,y_pred_ridge)]
        sns.barplot(x=['Random Forest Regressor','Gradient Boosting Regressor','Ridge'],y=y_values,hue=y_values,palette=('RdYlGn_r' if name!="R2" else 'RdYlGn') ,ax=ax)
        ax.set_ylabel('value')
        ax.set_title(f'{name} comparison')
        for i in ax.containers:
            ax.bar_label(i,fmt='%.2f',label_type='edge')
        ax.legend().remove()
        ax.xaxis.set_tick_params(rotation=45)
plot_compare()

# %% [markdown]
# # Plotting features importance Gradient Boosing Regressor

# %%
def plot_feature_importance(model, features) -> None:
    '''Plots feature importance for a given model'''
    plt.figure(figsize=(12,5))
    axis = plt.gca()
    sns.barplot(x=features,y=model.feature_importances_,palette='RdYlGn',hue=model.feature_importances_,ax=axis)    
    axis.set_xticks(range(len(features)))
    axis.set_xticklabels(shorten_labels(axis.get_xticklabels(),20))

    axis.xaxis.set_tick_params(rotation=90)
    plt.ylabel('Importance')
    plt.xlabel('Features')
    for bar in axis.containers:
        axis.bar_label(bar,fmt='%.2f',label_type='edge')
    plt.legend().remove()
    plt.show()

plot_feature_importance(gradient_model,df.columns[1:])

# %% [markdown]
# # Comparision between true and predicted values for each model

# %%
def true_vs_predicted(features, target, df, models) -> None:
    plt.figure(figsize=(15, 6))
    plt.plot(df.index, target, label='True values', color='red', linewidth=5)
    for model in models:
        color = (random.random(), random.random(), random.random())
        y_pred = model.predict(features)
        plt.plot(df.index, y_pred, color=color)
    plt.xscale('linear')
    plt.legend(['True values']+[model.__class__.__name__ for model in models])
true_vs_predicted(x,y,df,[forest_model,gradient_model,ridge_model])

# %% [markdown]
# # Guessing the life expectancy for selected countries using our models

# %%
def get_prediction(index, models=[forest_model, gradient_model, ridge_model], scaler=scaler, df=df):
    if index not in df.index:
        print(f'{index} not found in dataset')
        return
    values = df.loc[index].values
    target = values[0]
    features = values[1:]
    features = scaler.transform(features.reshape(1,-1))
    names = [model.__class__.__name__ for model in models]
    predictions = [round(model.predict(features)[0],2) for model in models]
    sns.barplot(x=names,y=predictions,palette='RdYlGn_r',hue=[abs(round(prediction-target,3)) for prediction in predictions])
    sns.lineplot(y=[target for i in range(len(models))],x=names,color='red',label=f'True = {target:.2f}')
    plt.ylabel('Target')
    plt.xlabel('Model')
    plt.xticks(rotation=45)
    plt.title(f'Prediction for {index}')
    plt.legend(title='Deviation from true',loc='lower right')
    plt.show()
get_prediction('Poland')
get_prediction('Japan')
get_prediction('Thailand')

# %% [markdown]
# # Conclusion regarding models

# %% [markdown]
# Although the Gradieng Boosing Models had worse scores in the initial testing, after experimenting with its parameters it has proven to be the most accurate model
#
# Addidtionaly, due to the weak correation between life expectancy and some of the indicators, maybe it would be better if they weren't taken into consideration.
